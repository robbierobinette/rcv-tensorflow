# %%
"""
solving pendulum using actor-critic model
"""

import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

import random
from collections import deque

# determines how to assign values to each state, i.e. takes the state
# and action (two-input model) and determines the corresponding value
class ActorCritic:
	def __init__(self, env, sess):
		self.env  = env
		self.sess = sess

		self.learning_rate = 0.001
		self.epsilon = 1.0
		self.epsilon_decay = .995
		self.gamma = .95
		self.tau   = .125

		# ===================================================================== #
		#                               Actor Model                             #
		# Chain rule: find the gradient of chaging the actor network params in  #
		# getting closest to the final value network predictions, i.e. de/dA    #
		# Calculate de/dA as = de/dC * dC/dA, where e is error, C critic, A act #
		# ===================================================================== #

		self.memory = deque(maxlen=2000)
		self.actor_state_input, self.actor_model = self.create_actor_model()
		_, self.target_actor_model = self.create_actor_model()

		self.actor_critic_grad = tf.placeholder(tf.float32,
			[None, self.env.action_space.shape[0]]) # where we will feed de/dC (from critic)

		actor_model_weights = self.actor_model.trainable_weights
		self.actor_grads = tf.gradients(self.actor_model.output,
			actor_model_weights, -self.actor_critic_grad) # dC/dA (from actor)
		grads = zip(self.actor_grads, actor_model_weights)
		self.optimize = Adam(self.learning_rate).apply_gradients(grads)

		# ===================================================================== #
		#                              Critic Model                             #
		# ===================================================================== #

		self.critic_state_input, self.critic_action_input, \
			self.critic_model = self.create_critic_model()
		_, _, self.target_critic_model = self.create_critic_model()

		self.critic_grads = tf.gradients(self.critic_model.output,
			self.critic_action_input) # where we calcaulte de/dC for feeding above

		# Initialize for later gradient calculations
		self.sess.run(tf.initialize_all_variables())

	# ========================================================================= #
	#                              Model Definitions                            #
	# ========================================================================= #

	def create_actor_model(self):
		state_input = Input(shape=self.env.observation_space.shape)
		h1 = Dense(24, activation='relu')(state_input)
		h2 = Dense(48, activation='relu')(h1)
		h3 = Dense(24, activation='relu')(h2)
		output = Dense(self.env.action_space.shape[0], activation='relu')(h3)

		model = Model(input=state_input, output=output)
		adam  = Adam(lr=0.001)
		model.compile(loss="mse", optimizer=adam)
		return state_input, model

	def create_critic_model(self):
		state_input = Input(shape=self.env.observation_space.shape)
		state_h1 = Dense(24, activation='relu')(state_input)
		state_h2 = Dense(48)(state_h1)

		action_input = Input(shape=self.env.action_space.shape)
		action_h1    = Dense(48)(action_input)

		merged    = Add()([state_h2, action_h1])
		merged_h1 = Dense(24, activation='relu')(merged)
		output = Dense(1, activation='relu')(merged_h1)
		model  = Model(input=[state_input,action_input], output=output)

		adam  = Adam(lr=0.001)
		model.compile(loss="mse", optimizer=adam)
		return state_input, action_input, model

	# ========================================================================= #
	#                               Model Training                              #
	# ========================================================================= #

	def remember(self, cur_state, action, reward, new_state, done):
		self.memory.append([cur_state, action, reward, new_state, done])

	def _train_actor(self, samples):
		for sample in samples:
			cur_state, action, reward, new_state, _ = sample
			predicted_action = self.actor_model.predict(cur_state)
			grads = self.sess.run(self.critic_grads, feed_dict={
				self.critic_state_input:  cur_state,
				self.critic_action_input: predicted_action
			})[0]

			self.sess.run(self.optimize, feed_dict={
				self.actor_state_input: cur_state,
				self.actor_critic_grad: grads
			})

	def _train_critic(self, samples):
		for sample in samples:
			cur_state, action, reward, new_state, done = sample
			if not done:
				target_action = self.target_actor_model.predict(new_state)
				future_reward = self.target_critic_model.predict(
					[new_state, target_action])[0][0]
				reward += self.gamma * future_reward
			self.critic_model.fit([cur_state, action], reward, verbose=0)

	def train(self):
		batch_size = 32
		if len(self.memory) < batch_size:
			return

		rewards = []
		samples = random.sample(self.memory, batch_size)
		self._train_critic(samples)
		self._train_actor(samples)

	# ========================================================================= #
	#                         Target Model Updating                             #
	# ========================================================================= #

	def _update_actor_target(self):
		actor_model_weights  = self.actor_model.get_weights()
		actor_target_weights = self.target_critic_model.get_weights()

		for i in range(len(actor_target_weights)):
			actor_target_weights[i] = actor_model_weights[i]
		self.target_critic_model.set_weights(actor_target_weights)

	def _update_critic_target(self):
		critic_model_weights  = self.critic_model.get_weights()
		critic_target_weights = self.critic_target_model.get_weights()

		for i in range(len(critic_target_weights)):
			critic_target_weights[i] = critic_model_weights[i]
		self.critic_target_model.set_weights(critic_target_weights)

	def update_target(self):
		self._update_actor_target()
		self._update_critic_target()

	# ========================================================================= #
	#                              Model Predictions                            #
	# ========================================================================= #

	def act(self, cur_state):
		self.epsilon *= self.epsilon_decay
		if np.random.random() < self.epsilon:
			return self.env.action_space.sample()
		return self.actor_model.predict(cur_state)

def main():
	sess = tf.Session()
	K.set_session(sess)
	env = gym.make("Pendulum-v0")
	actor_critic = ActorCritic(env, sess)

	num_trials = 10000
	trial_len  = 500

	cur_state = env.reset()
	action = env.action_space.sample()
	while True:
		env.render()
		cur_state = cur_state.reshape((1, env.observation_space.shape[0]))
		action = actor_critic.act(cur_state)
		action = action.reshape((1, env.action_space.shape[0]))

		new_state, reward, done, _ = env.step(action)
		new_state = new_state.reshape((1, env.observation_space.shape[0]))

		actor_critic.remember(cur_state, action, reward, new_state, done)
		actor_critic.train()

		cur_state = new_state

if __name__ == "__main__":
	main()
# Out:
# EP0 EpisodeReward=-1197.0349276910574
# EP1 EpisodeReward=-1157.1021518464945
# EP2 EpisodeReward=-1320.4990821890976
# EP3 EpisodeReward=-1574.636258871565
# EP4 EpisodeReward=-1628.4440282801193
# EP5 EpisodeReward=-1394.1604630303448
# EP6 EpisodeReward=-1007.5916826425843
# EP7 EpisodeReward=-1468.143531486667
# EP8 EpisodeReward=-1143.6199335162257
# EP9 EpisodeReward=-1246.0892575378655
# EP10 EpisodeReward=-1411.684626907291
# EP11 EpisodeReward=-1181.1774731727062
# EP12 EpisodeReward=-1398.618995216745
# EP13 EpisodeReward=-1494.5514431538531
# EP14 EpisodeReward=-1504.1857346248687
# EP15 EpisodeReward=-1497.0220606498956
# EP16 EpisodeReward=-1522.264864640859
# EP17 EpisodeReward=-1379.51801746054
# EP18 EpisodeReward=-1497.7223422730062
# EP19 EpisodeReward=-1464.7656999337905
# EP20 EpisodeReward=-1495.2041964363093
# EP21 EpisodeReward=-1530.8440036620098
# EP22 EpisodeReward=-1565.916066716856
# EP23 EpisodeReward=-1536.6801107537367
# EP24 EpisodeReward=-1602.6798753866312
# EP25 EpisodeReward=-1553.1514572872215
# EP26 EpisodeReward=-1504.522256675111
# EP27 EpisodeReward=-1538.9852476586423
# EP28 EpisodeReward=-1542.955199236778
# EP29 EpisodeReward=-1521.0650435214375
# EP30 EpisodeReward=-1528.0555918153113
# EP31 EpisodeReward=-1403.6849079054082
# EP32 EpisodeReward=-1557.8276958307365
# EP33 EpisodeReward=-1495.0525253266796
# EP34 EpisodeReward=-1426.6582658972477
# EP35 EpisodeReward=-1501.2179640306103
# EP36 EpisodeReward=-1488.5224342512831
# EP37 EpisodeReward=-1528.8832181713617
# EP38 EpisodeReward=-1488.8522902045943
# EP39 EpisodeReward=-1584.2696938268643
# EP40 EpisodeReward=-1417.9128749753556
# EP41 EpisodeReward=-1368.5167170625061
# EP42 EpisodeReward=-1364.7038810819608
# EP43 EpisodeReward=-1445.6487998334799
# EP44 EpisodeReward=-1567.649642745828
# EP45 EpisodeReward=-1387.7562478492002
# EP46 EpisodeReward=-1453.326818395119
# EP47 EpisodeReward=-1348.7792011906342
# EP48 EpisodeReward=-1367.377341844584
# EP49 EpisodeReward=-1490.4073762349851
# EP50 EpisodeReward=-1485.0361441369555
# EP51 EpisodeReward=-1450.7575055023096
# EP52 EpisodeReward=-1465.597741737314
# EP53 EpisodeReward=-1506.5272706612677
# EP54 EpisodeReward=-1522.961231994579
# EP55 EpisodeReward=-1335.9060363980252
# EP56 EpisodeReward=-1501.2902570240662
# EP57 EpisodeReward=-1403.2951244185376
# EP58 EpisodeReward=-1347.9181865064609
# EP59 EpisodeReward=-1465.8468151766829
# EP60 EpisodeReward=-1483.1658993126662
# EP61 EpisodeReward=-1425.2692711260972
# EP62 EpisodeReward=-1280.0254085996162
# EP63 EpisodeReward=-1381.3648036464438
# EP64 EpisodeReward=-1406.1310872515114
# EP65 EpisodeReward=-1379.5976706785998
# EP66 EpisodeReward=-1464.188760041707
# EP67 EpisodeReward=-1498.9224871283425
# EP68 EpisodeReward=-1167.1613281629154
# EP69 EpisodeReward=-1395.7046391482488
# EP70 EpisodeReward=-1111.882277809244
# EP71 EpisodeReward=-1309.5424429738714
# EP72 EpisodeReward=-1461.3423104313401
# EP73 EpisodeReward=-1340.1413497460994
# EP74 EpisodeReward=-1381.3976133475237
# EP75 EpisodeReward=-1360.7295343683718
# EP76 EpisodeReward=-1514.0373744308886
# EP77 EpisodeReward=-1327.3234468410496
# EP78 EpisodeReward=-1394.4197767900737
# EP79 EpisodeReward=-1374.0960520094284
# EP80 EpisodeReward=-1450.1682022476596
# EP81 EpisodeReward=-1191.4963534997833
# EP82 EpisodeReward=-1447.8501678167752
# EP83 EpisodeReward=-1163.4205001011762
# EP84 EpisodeReward=-1229.4458277880283
# EP85 EpisodeReward=-1296.90273647842
# EP86 EpisodeReward=-1483.5543046817802
# EP87 EpisodeReward=-1511.405077460013
# EP88 EpisodeReward=-1269.4652219291663
# EP89 EpisodeReward=-1262.0329427637378
# EP90 EpisodeReward=-1420.9913731864615
# EP91 EpisodeReward=-1530.3904793048348
# EP92 EpisodeReward=-1262.007133473338
# EP93 EpisodeReward=-1373.4762074936075
# EP94 EpisodeReward=-1301.420120848466
# EP95 EpisodeReward=-1230.3418423766648
# EP96 EpisodeReward=-1157.464855349853
# EP97 EpisodeReward=-1170.1156326945286
# EP98 EpisodeReward=-1393.193708312235
# EP99 EpisodeReward=-1494.5155406874962
# EP100 EpisodeReward=-1435.5000097847487
# EP101 EpisodeReward=-1365.7305180317962
# EP102 EpisodeReward=-910.7044214949777
# EP103 EpisodeReward=-1318.5941797855758
# EP104 EpisodeReward=-1513.5470920485002
# EP105 EpisodeReward=-1320.1054405841976
# EP106 EpisodeReward=-1367.6060527192974
# EP107 EpisodeReward=-1316.1100952547063
# EP108 EpisodeReward=-1221.371429733938
# EP109 EpisodeReward=-904.1728091906091
# EP110 EpisodeReward=-1218.495977330754
# EP111 EpisodeReward=-767.3794676639824
# EP112 EpisodeReward=-1354.9496521812619
# EP113 EpisodeReward=-966.1303950693217
# EP114 EpisodeReward=-1204.307471341498
# EP115 EpisodeReward=-1486.0931578616046
# EP116 EpisodeReward=-1512.5143184363903
# EP117 EpisodeReward=-1187.0992606480477
# EP118 EpisodeReward=-1379.0294065810801
# EP119 EpisodeReward=-1228.283534839425
# EP120 EpisodeReward=-1474.1875359299092
# EP121 EpisodeReward=-1500.198225495459
# EP122 EpisodeReward=-1419.6533522009688
# EP123 EpisodeReward=-1344.1866805738102
# EP124 EpisodeReward=-1297.5647731879424
# EP125 EpisodeReward=-1201.9090880969345
# EP126 EpisodeReward=-906.1024366918009
# EP127 EpisodeReward=-1296.758743847274
# EP128 EpisodeReward=-1001.9313084598822
# EP129 EpisodeReward=-755.7066431179237
# EP130 EpisodeReward=-898.1719037870454
# EP131 EpisodeReward=-1251.6262023964412
# EP132 EpisodeReward=-1130.5363525808857
# EP133 EpisodeReward=-1080.1587618957415
# EP134 EpisodeReward=-769.2954232955136
# EP135 EpisodeReward=-877.2226070660942
# EP136 EpisodeReward=-857.3583786064559
# EP137 EpisodeReward=-878.3577663451862
# EP138 EpisodeReward=-1362.1884939314114
# EP139 EpisodeReward=-1541.4886609605492
# EP140 EpisodeReward=-1330.7159643962723
# EP141 EpisodeReward=-1481.2308730438544
# EP142 EpisodeReward=-1510.5795021430376
# EP143 EpisodeReward=-1425.0979616786542
# EP144 EpisodeReward=-1463.6734882659
# EP145 EpisodeReward=-1512.7481326893308
# EP146 EpisodeReward=-1347.267066676113
# EP147 EpisodeReward=-1277.5980928243932
# EP148 EpisodeReward=-1238.209674289405
# EP149 EpisodeReward=-1502.5137547074562
# EP150 EpisodeReward=-1416.0385699326089
# EP151 EpisodeReward=-1347.864878063112
# EP152 EpisodeReward=-1372.0439151425603
# EP153 EpisodeReward=-1371.0989272691745
# EP154 EpisodeReward=-1367.575495747989
# EP155 EpisodeReward=-1344.9486016236447
# EP156 EpisodeReward=-1412.2138171413214
# EP157 EpisodeReward=-1363.828976811145
# EP158 EpisodeReward=-1230.977158010713
# EP159 EpisodeReward=-1363.174783716829
# EP160 EpisodeReward=-1273.7036176466936
# EP161 EpisodeReward=-1075.7267205022363
# EP162 EpisodeReward=-1361.1058007753882
# EP163 EpisodeReward=-1336.2015860540705
# EP164 EpisodeReward=-888.1644376056825
# EP165 EpisodeReward=-927.120797408343
# EP166 EpisodeReward=-883.2612709265828
# EP167 EpisodeReward=-1243.0175293676439
# EP168 EpisodeReward=-644.4727511198417
# EP169 EpisodeReward=-646.1488373114172
# EP170 EpisodeReward=-954.9116820116677
# EP171 EpisodeReward=-911.7324524037111
# EP172 EpisodeReward=-916.33615445664
# EP173 EpisodeReward=-1075.935742845856
# EP174 EpisodeReward=-899.4425442829274
# EP175 EpisodeReward=-1264.2810419745713
# EP176 EpisodeReward=-659.3339634056271
# EP177 EpisodeReward=-1128.816293656583
# EP178 EpisodeReward=-899.9712117896867
# EP179 EpisodeReward=-1052.7065071880954
# EP180 EpisodeReward=-1200.368905608431
# EP181 EpisodeReward=-1172.4621535999472
# EP182 EpisodeReward=-772.610790306243
# EP183 EpisodeReward=-1393.31128856007
# EP184 EpisodeReward=-1025.9182327599203
# EP185 EpisodeReward=-1080.577256537643
# EP186 EpisodeReward=-395.15604411207505
# EP187 EpisodeReward=-1113.1092778883492
# EP188 EpisodeReward=-1170.7084047517426
# EP189 EpisodeReward=-396.8338849694324
# EP190 EpisodeReward=-1005.9789860745866
# EP191 EpisodeReward=-1319.5777279275364
# EP192 EpisodeReward=-605.9803072630663
# EP193 EpisodeReward=-397.6193902981733
# EP194 EpisodeReward=-1426.4192111011382
# EP195 EpisodeReward=-1544.6846791951807
# EP196 EpisodeReward=-1557.944604142235
# EP197 EpisodeReward=-1310.2300278299335
# EP198 EpisodeReward=-1438.4749756610945
# EP199 EpisodeReward=-1254.909996729787
# EP200 EpisodeReward=-1487.108215703097
# EP201 EpisodeReward=-1455.768147876424
# EP202 EpisodeReward=-134.94316165909527
# EP203 EpisodeReward=-1559.2958071180715
# EP204 EpisodeReward=-1437.9862106285996
# EP205 EpisodeReward=-1291.1880640963516
# EP206 EpisodeReward=-1519.7738347496024
# EP207 EpisodeReward=-1169.2419871493482
# EP208 EpisodeReward=-1381.9236710694
# EP209 EpisodeReward=-1183.7638551273678
# EP210 EpisodeReward=-1560.7478880449623
# EP211 EpisodeReward=-1143.552437600425
# EP212 EpisodeReward=-1095.5408942391293
# EP213 EpisodeReward=-1285.373313890074
# EP214 EpisodeReward=-1192.3218601710996
# EP215 EpisodeReward=-1413.8115737597316
# EP216 EpisodeReward=-1029.6900609583452
# EP217 EpisodeReward=-140.35913673765538
# EP218 EpisodeReward=-1453.0758449287491
# EP219 EpisodeReward=-1251.9484972298221
# EP220 EpisodeReward=-1510.5552219713288
# EP221 EpisodeReward=-341.970770033
# EP222 EpisodeReward=-1549.8515095290318
# EP223 EpisodeReward=-1276.1798832102465
# EP224 EpisodeReward=-398.5036420369053
# EP225 EpisodeReward=-1249.4348709525918
# EP226 EpisodeReward=-1134.2725491660074
# EP227 EpisodeReward=-1129.6742350374086
# EP228 EpisodeReward=-1568.6462691500278
# EP229 EpisodeReward=-1099.3412347711583
# EP230 EpisodeReward=-1417.9949822451283
# EP231 EpisodeReward=-791.987152874864
# EP232 EpisodeReward=-1529.0768315017353
# EP233 EpisodeReward=-1255.9484178969437
# EP234 EpisodeReward=-1260.9120951621233
# EP235 EpisodeReward=-786.7749427847775
# EP236 EpisodeReward=-1124.8313206043508
# EP237 EpisodeReward=-1005.9084251288547
# EP238 EpisodeReward=-867.0050153473538
# EP239 EpisodeReward=-1489.7158397329476
# EP240 EpisodeReward=-1231.276734556978
# EP241 EpisodeReward=-1495.4147431817946
# EP242 EpisodeReward=-1272.3623942039835
# EP243 EpisodeReward=-1320.2855564702488
# EP244 EpisodeReward=-1177.4092785860355
# EP245 EpisodeReward=-1271.5892047227069
# EP246 EpisodeReward=-1537.758919032965
# EP247 EpisodeReward=-1245.1603316347366
# EP248 EpisodeReward=-1377.588021562984
# EP249 EpisodeReward=-1255.1709454665095
# EP250 EpisodeReward=-1539.8014499742924
# EP251 EpisodeReward=-1461.0587335431962
# EP252 EpisodeReward=-1240.5367893718003
# EP253 EpisodeReward=-1547.6859386797728
# EP254 EpisodeReward=-1163.7548427062138
# EP255 EpisodeReward=-1227.5366685499152
# EP256 EpisodeReward=-1236.3498397610201
# EP257 EpisodeReward=-1241.3490137270653
# EP258 EpisodeReward=-1259.9991519351877
# EP259 EpisodeReward=-1256.0523911059972
# EP260 EpisodeReward=-649.7271577606153
# EP261 EpisodeReward=-655.3629801930177
# EP262 EpisodeReward=-1462.4593327351101
# EP263 EpisodeReward=-1273.2379741568311
# EP264 EpisodeReward=-1551.7221700723032
# EP265 EpisodeReward=-1341.1310452588061
# EP266 EpisodeReward=-1512.5472058990347
# EP267 EpisodeReward=-1459.89776279012
# EP268 EpisodeReward=-916.0711785664
# EP269 EpisodeReward=-1427.3407797396799
# EP270 EpisodeReward=-1142.1689846091192
# EP271 EpisodeReward=-1114.621132028607
# EP272 EpisodeReward=-1003.3674306891777
# EP273 EpisodeReward=-1163.2364139419149
# EP274 EpisodeReward=-1011.1660417827532
# EP275 EpisodeReward=-1081.0869815284716
# EP276 EpisodeReward=-1135.2104393016336
# EP277 EpisodeReward=-466.6951708554452
# EP278 EpisodeReward=-1101.435380208967
# EP279 EpisodeReward=-937.6964585174766
# EP280 EpisodeReward=-1084.8638079636107
# EP281 EpisodeReward=-665.163802129226
# EP282 EpisodeReward=-918.9708798573361
# EP283 EpisodeReward=-1320.1962800386718
# EP284 EpisodeReward=-1373.5544923692864
# EP285 EpisodeReward=-1312.1236328470109
# EP286 EpisodeReward=-1528.0243048811974
# EP287 EpisodeReward=-1608.066832913157
# EP288 EpisodeReward=-1345.332970642305
# EP289 EpisodeReward=-1346.6355394288303
# EP290 EpisodeReward=-1432.0791343927538
# EP291 EpisodeReward=-1471.451000464888
# EP292 EpisodeReward=-1490.9637686939145
# EP293 EpisodeReward=-1551.6210495409728
# EP294 EpisodeReward=-1531.0755729393152
# EP295 EpisodeReward=-1394.679266639443
# EP296 EpisodeReward=-1534.5406209273076
# EP297 EpisodeReward=-1226.423372877908
# EP298 EpisodeReward=-1408.5516756930695
# EP299 EpisodeReward=-1621.0039605706345
# EP300 EpisodeReward=-1636.643054859425
# EP301 EpisodeReward=-1521.507141108804
# EP302 EpisodeReward=-1516.965874257452
# EP303 EpisodeReward=-1523.1216427371821
# EP304 EpisodeReward=-1385.9143673542228
# EP305 EpisodeReward=-1500.5610711604404
# EP306 EpisodeReward=-1512.8853133505106
# EP307 EpisodeReward=-1517.9662517277618
# EP308 EpisodeReward=-1384.0098719844457
# EP309 EpisodeReward=-1463.544014883347
# EP310 EpisodeReward=-1428.6104773092673
# EP311 EpisodeReward=-1329.7345726625488
# EP312 EpisodeReward=-1581.9059898619007
# EP313 EpisodeReward=-1536.7598304404949
# EP314 EpisodeReward=-1325.509807175715
# EP315 EpisodeReward=-1629.6527879772073
# EP316 EpisodeReward=-1619.0953107756934
# EP317 EpisodeReward=-1110.0849141398037
# EP318 EpisodeReward=-1534.6598510956583
# EP319 EpisodeReward=-1619.4501251988518
# EP320 EpisodeReward=-1534.9007052469747
# EP321 EpisodeReward=-1627.2089285950876
# EP322 EpisodeReward=-1452.7043948789817
# EP323 EpisodeReward=-1221.3391434807031
# EP324 EpisodeReward=-1567.51250890443
# EP325 EpisodeReward=-1618.6378133998455
# EP326 EpisodeReward=-1530.4402768044104
# EP327 EpisodeReward=-1568.860648059652
# EP328 EpisodeReward=-1562.0368859102152
# EP329 EpisodeReward=-1476.1352544547433
# EP330 EpisodeReward=-1468.714035685072
# EP331 EpisodeReward=-1534.809866930886
# EP332 EpisodeReward=-1430.8298831579446
# EP333 EpisodeReward=-1467.0227023646132
# EP334 EpisodeReward=-1393.6180829795476
# EP335 EpisodeReward=-1254.4057520542058
# EP336 EpisodeReward=-1527.0645034945678
# EP337 EpisodeReward=-1356.8219473512627
# EP338 EpisodeReward=-1094.665729895364
# EP339 EpisodeReward=-1032.4894808386025
# EP340 EpisodeReward=-1114.0374719295005
# EP341 EpisodeReward=-1072.0773627726262
# EP342 EpisodeReward=-1255.810504752936
# EP343 EpisodeReward=-1250.4308928790563
# EP344 EpisodeReward=-1463.8974917266082
# EP345 EpisodeReward=-782.5212531522454
# EP346 EpisodeReward=-805.511381408229
# EP347 EpisodeReward=-1356.346452626654
# EP348 EpisodeReward=-1252.3233897713897
# EP349 EpisodeReward=-1404.2722424892245
# EP350 EpisodeReward=-1367.264081534897
# EP351 EpisodeReward=-1352.7303978466111
# EP352 EpisodeReward=-1371.5148217238675
# EP353 EpisodeReward=-1384.76717806981
# EP354 EpisodeReward=-1457.285746916281
# EP355 EpisodeReward=-1490.2504679208957
# EP356 EpisodeReward=-1518.05781607782
# EP357 EpisodeReward=-1390.666254821488
# EP358 EpisodeReward=-1535.3792555369348
# EP359 EpisodeReward=-1201.533413889934
# EP360 EpisodeReward=-1506.5441475325176
# EP361 EpisodeReward=-1494.2516611176961
# EP362 EpisodeReward=-1421.820525393905
# EP363 EpisodeReward=-1516.9313268878152
# EP364 EpisodeReward=-1495.8426441774147
# EP365 EpisodeReward=-1617.633946315071
# EP366 EpisodeReward=-1514.4987854301583
# EP367 EpisodeReward=-1406.2254824819981
# EP368 EpisodeReward=-1405.3073085000008
# EP369 EpisodeReward=-1551.9589330542349
# EP370 EpisodeReward=-1516.1097354491153
# EP371 EpisodeReward=-1502.0037509573037
# EP372 EpisodeReward=-1570.361747073504
# EP373 EpisodeReward=-1619.8032057587154
# EP374 EpisodeReward=-1513.907043031777
# EP375 EpisodeReward=-1536.8389536081713
# EP376 EpisodeReward=-1371.1402372260625
# EP377 EpisodeReward=-1590.7801311781182
# EP378 EpisodeReward=-1513.8175267440954
# EP379 EpisodeReward=-1536.7522437420787
# EP380 EpisodeReward=-1536.2003222978685
# EP381 EpisodeReward=-1482.7759577420811
# EP382 EpisodeReward=-1410.9830147736952
# EP383 EpisodeReward=-1490.4660891043625
# EP384 EpisodeReward=-1610.9118869291297
# EP385 EpisodeReward=-1640.4504295875597
# EP386 EpisodeReward=-1518.1935991405933
# EP387 EpisodeReward=-1641.1676352784136
# EP388 EpisodeReward=-1521.4263289350067
# EP389 EpisodeReward=-1502.9858010952944
# EP390 EpisodeReward=-1585.6656793857471
# EP391 EpisodeReward=-1394.9893284704456
# EP392 EpisodeReward=-1420.531038577441
# EP393 EpisodeReward=-1496.8597176066219
# EP394 EpisodeReward=-1631.9490199478796
# EP395 EpisodeReward=-1549.4431604654321
# EP396 EpisodeReward=-1401.671019643206
# EP397 EpisodeReward=-1417.4954405965552
# EP398 EpisodeReward=-1529.7666574056066
# EP399 EpisodeReward=-1508.185631927921
# EP400 EpisodeReward=-1489.5974296946006
# EP401 EpisodeReward=-1494.2207604229568
# EP402 EpisodeReward=-1526.980623062864
# EP403 EpisodeReward=-1536.6097514210483
# EP404 EpisodeReward=-1611.5307321094747
# EP405 EpisodeReward=-1367.4645983558526
# EP406 EpisodeReward=-1503.1122652745537
# EP407 EpisodeReward=-1636.9879242992984
# EP408 EpisodeReward=-1621.9056318471282
# EP409 EpisodeReward=-1541.5356923277866
# EP410 EpisodeReward=-1521.846177334053
# EP411 EpisodeReward=-1484.0863390277434
# EP412 EpisodeReward=-1548.0060887805716
# EP413 EpisodeReward=-1510.7871727312165
# EP414 EpisodeReward=-1534.5585742437877
# EP415 EpisodeReward=-1522.8252628820733
# EP416 EpisodeReward=-1521.8632284730384
# EP417 EpisodeReward=-1482.7962611860207
# EP418 EpisodeReward=-1597.2533265005043
# EP419 EpisodeReward=-1512.5905584659877
# EP420 EpisodeReward=-1641.6316048773092
# EP421 EpisodeReward=-1572.409163248992
# EP422 EpisodeReward=-1446.2607560430288
# EP423 EpisodeReward=-1499.0830242847737
# EP424 EpisodeReward=-1631.5760442533096
# EP425 EpisodeReward=-1638.062862275342
# EP426 EpisodeReward=-1605.396022556947
# EP427 EpisodeReward=-1501.865625592663
# EP428 EpisodeReward=-1648.136565915224
# EP429 EpisodeReward=-1601.777098552226
# EP430 EpisodeReward=-1460.6592433394135
# EP431 EpisodeReward=-1449.8281826849711
# EP432 EpisodeReward=-1575.6947668188084
# EP433 EpisodeReward=-1543.2956482987038
# EP434 EpisodeReward=-1527.025171789951
# EP435 EpisodeReward=-1507.6536974074459
# EP436 EpisodeReward=-1529.6609356099354
# EP437 EpisodeReward=-1528.9150550358527
# EP438 EpisodeReward=-1464.4362511671543
# EP439 EpisodeReward=-1533.3930060203863
# EP440 EpisodeReward=-1472.5430836863832
# EP441 EpisodeReward=-1439.987226771509
# EP442 EpisodeReward=-1632.8446925701037
# EP443 EpisodeReward=-1210.3822497331307
# EP444 EpisodeReward=-1537.7393063037007
# EP445 EpisodeReward=-1616.1454490600618
# EP446 EpisodeReward=-1470.7377045249737
# EP447 EpisodeReward=-1400.6412023296377
# EP448 EpisodeReward=-1521.5970025549962
# EP449 EpisodeReward=-1620.9700799811187
# EP450 EpisodeReward=-1629.1995456699751
# EP451 EpisodeReward=-1600.609665056756
# EP452 EpisodeReward=-1522.4695127205534
# EP453 EpisodeReward=-1310.5536231910448
# EP454 EpisodeReward=-1519.057338960774
# EP455 EpisodeReward=-1346.9361981471404
# EP456 EpisodeReward=-1333.280289265062
# EP457 EpisodeReward=-1089.285117214896
# EP458 EpisodeReward=-1615.1595722428474
# EP459 EpisodeReward=-1377.5031325998266
# EP460 EpisodeReward=-1536.282339643397
# EP461 EpisodeReward=-1035.9563667965024
# EP462 EpisodeReward=-1630.1244491165407
# EP463 EpisodeReward=-1634.2029683598194
# EP464 EpisodeReward=-1473.2279655987336
# EP465 EpisodeReward=-1637.231070172755
# EP466 EpisodeReward=-1533.260762312078
# EP467 EpisodeReward=-1518.3371465114394
# EP468 EpisodeReward=-1507.7195887231308
# EP469 EpisodeReward=-1608.8630096176335
# EP470 EpisodeReward=-1593.7507316881415
# EP471 EpisodeReward=-1372.3906599087684
# EP472 EpisodeReward=-1473.231268604575
# EP473 EpisodeReward=-1400.1449319629114
# EP474 EpisodeReward=-1622.272976797134
# EP475 EpisodeReward=-1534.5452243403765
# EP476 EpisodeReward=-1545.6952881790185
# EP477 EpisodeReward=-1205.7298575947696
# EP478 EpisodeReward=-1389.2717970241476
# EP479 EpisodeReward=-1610.667593253733
# EP480 EpisodeReward=-1093.1024725329946
# EP481 EpisodeReward=-1531.615187846591
# EP482 EpisodeReward=-1577.5291560427638
# EP483 EpisodeReward=-1530.1169353352363
# EP484 EpisodeReward=-1536.900243039498
# EP485 EpisodeReward=-1455.5595333282995
# EP486 EpisodeReward=-1370.2571907954339
# EP487 EpisodeReward=-1351.2725961790052
# EP488 EpisodeReward=-1361.5327707956064
# EP489 EpisodeReward=-1622.9093312059917
# EP490 EpisodeReward=-1506.0926083417726
# EP491 EpisodeReward=-1608.4293061352996
# EP492 EpisodeReward=-1608.0168334136895
# EP493 EpisodeReward=-1641.5053619276669
# EP494 EpisodeReward=-1386.67471801026
# EP495 EpisodeReward=-1504.1974518664613
# EP496 EpisodeReward=-1555.6726829213537
# EP497 EpisodeReward=-1620.3304492069444
# EP498 EpisodeReward=-1493.0287263875318
# EP499 EpisodeReward=-1364.6856269917341
# EP500 EpisodeReward=-1622.349351461873
# EP501 EpisodeReward=-1295.86302906539
# EP502 EpisodeReward=-1355.3829933771456
# EP503 EpisodeReward=-1407.5493331657249
# EP504 EpisodeReward=-1390.76318792034
# EP505 EpisodeReward=-1381.339228583304
# EP506 EpisodeReward=-1480.4964973331375
# EP507 EpisodeReward=-1431.001944053229
# EP508 EpisodeReward=-1241.8921207953965
# EP509 EpisodeReward=-1427.1338976781265
# EP510 EpisodeReward=-1370.3748786364333
# EP511 EpisodeReward=-1496.23049458291
# EP512 EpisodeReward=-1452.9941864109123
# EP513 EpisodeReward=-1521.6670017037632
# EP514 EpisodeReward=-1453.3528942197304
# EP515 EpisodeReward=-1507.393698526968
# EP516 EpisodeReward=-1347.1648501016648
# EP517 EpisodeReward=-1415.4836129985063
# EP518 EpisodeReward=-1278.2352188064924
# EP519 EpisodeReward=-1392.4848643104044
# EP520 EpisodeReward=-1292.6146884346424
# EP521 EpisodeReward=-1142.818726458513
# EP522 EpisodeReward=-1085.7668698088485
# EP523 EpisodeReward=-1184.443446166331
# EP524 EpisodeReward=-1233.9036594470892
# EP525 EpisodeReward=-1026.2205006261877
# EP526 EpisodeReward=-1028.5075890363023
# EP527 EpisodeReward=-926.7292773726688
# EP528 EpisodeReward=-133.03696612070866
# EP529 EpisodeReward=-1287.7960205163647
# EP530 EpisodeReward=-1307.7840463809298
# EP531 EpisodeReward=-1431.4414399314921
# EP532 EpisodeReward=-2.570611142134753
# EP533 EpisodeReward=-1507.4710916031743
# EP534 EpisodeReward=-1403.8352224037967
# EP535 EpisodeReward=-1359.7655099397084
# EP536 EpisodeReward=-1051.03822058417
# EP537 EpisodeReward=-1352.7901432354108
# EP538 EpisodeReward=-1170.2185879921901
# EP539 EpisodeReward=-1075.5296976521172
# EP540 EpisodeReward=-1201.6093809542176
# EP541 EpisodeReward=-275.49227294008085
# EP542 EpisodeReward=-278.4716326975749
# EP543 EpisodeReward=-1200.2867971761423
# EP544 EpisodeReward=-276.21997323053336
# EP545 EpisodeReward=-701.428693767444
# EP546 EpisodeReward=-405.1480709887571
# EP547 EpisodeReward=-837.9972280372525
# EP548 EpisodeReward=-534.7625234121649
# EP549 EpisodeReward=-136.47828774715788
# EP550 EpisodeReward=-133.5555897207034
# EP551 EpisodeReward=-265.57531342549174
# EP552 EpisodeReward=-136.64755254081464
# EP553 EpisodeReward=-1258.4213180884628
# EP554 EpisodeReward=-392.7646961448068
# EP555 EpisodeReward=-687.581478862897
# EP556 EpisodeReward=-659.0931737589215
# EP557 EpisodeReward=-678.2514574159316
# EP558 EpisodeReward=-1129.6393045208326
# EP559 EpisodeReward=-926.8498555355502
# EP560 EpisodeReward=-258.4264922930957
# EP561 EpisodeReward=-646.1584794147714
# EP562 EpisodeReward=-976.0955670905444
# EP563 EpisodeReward=-669.5103353058257
# EP564 EpisodeReward=-254.23834807410492
# EP565 EpisodeReward=-911.1259540146224
# EP566 EpisodeReward=-0.38200752354157025
# EP567 EpisodeReward=-400.7607518635288
# EP568 EpisodeReward=-2.569349433246293
# EP569 EpisodeReward=-138.17217640856336
# EP570 EpisodeReward=-669.1341828377977
# EP571 EpisodeReward=-133.5405821993229
# EP572 EpisodeReward=-265.8191680744557
# EP573 EpisodeReward=-0.7819509117021699
# EP574 EpisodeReward=-130.03241932986842
# EP575 EpisodeReward=-854.1289410626425
# EP576 EpisodeReward=-7.432626142464898
# EP577 EpisodeReward=-528.5223070161654
# EP578 EpisodeReward=-261.7708994430262
# EP579 EpisodeReward=-134.07655571374704
# EP580 EpisodeReward=-2.792893300698088
# EP581 EpisodeReward=-262.0139482890782
# EP582 EpisodeReward=-382.2782715493209
# EP583 EpisodeReward=-524.1218832335111
# EP584 EpisodeReward=-792.5334132289485
# EP585 EpisodeReward=-1077.1602773807272
# EP586 EpisodeReward=-557.9387853079697
# EP587 EpisodeReward=-1351.3059552634681
# EP588 EpisodeReward=-1231.0987487837567
# EP589 EpisodeReward=-1456.9736763224287
# EP590 EpisodeReward=-1206.1631247967864
# EP591 EpisodeReward=-1237.7114519063266
# EP592 EpisodeReward=-1165.3649137128923
# EP593 EpisodeReward=-1304.5262216424287
# EP594 EpisodeReward=-1312.0440682949195
# EP595 EpisodeReward=-1290.3514968874415
# EP596 EpisodeReward=-1400.5933818635954
# EP597 EpisodeReward=-1186.8738459315623
# EP598 EpisodeReward=-1427.5800835489645
# EP599 EpisodeReward=-1382.7153693197279
# EP600 EpisodeReward=-1245.532065098791
# EP601 EpisodeReward=-1333.2209131070747
# EP602 EpisodeReward=-911.2198236523755
# EP603 EpisodeReward=-1346.8624980535815
# EP604 EpisodeReward=-1383.7437102078657
# EP605 EpisodeReward=-1358.162701852762
# EP606 EpisodeReward=-1345.8535946470602
# EP607 EpisodeReward=-1470.156886251421
# EP608 EpisodeReward=-1234.1221656200291
# EP609 EpisodeReward=-1401.5402510463664
# EP610 EpisodeReward=-1526.280193803841
# EP611 EpisodeReward=-1351.7319127814524
# EP612 EpisodeReward=-1366.0289804858269
# EP613 EpisodeReward=-1401.0907025302197
# EP614 EpisodeReward=-1386.7105027699436
# EP615 EpisodeReward=-1404.0749275904072
# EP616 EpisodeReward=-1500.3845723557129
# EP617 EpisodeReward=-1214.0062071457016
# EP618 EpisodeReward=-1319.1128423503308
# EP619 EpisodeReward=-1371.1115905373958
# EP620 EpisodeReward=-1392.0357934404303
# EP621 EpisodeReward=-1435.078692383202
# EP622 EpisodeReward=-1522.0602912127026
# EP623 EpisodeReward=-1227.6538721296492
# EP624 EpisodeReward=-1339.4144114759374
# EP625 EpisodeReward=-1261.7477511948557
# EP626 EpisodeReward=-1521.2741232787484
# EP627 EpisodeReward=-1436.246508524999
# EP628 EpisodeReward=-1322.9171635883265
# EP629 EpisodeReward=-1358.1127998684058
# EP630 EpisodeReward=-1223.7245521138502
# EP631 EpisodeReward=-1170.2578068073608
# EP632 EpisodeReward=-1459.5730976046661
# EP633 EpisodeReward=-1284.340061329545
# EP634 EpisodeReward=-1229.2083332255204
# EP635 EpisodeReward=-1327.2624635477705
# EP636 EpisodeReward=-1516.3150056945715
# EP637 EpisodeReward=-1317.2906243429065
# EP638 EpisodeReward=-1538.5290511633061
# EP639 EpisodeReward=-1524.1611594608644
# EP640 EpisodeReward=-1546.5121612313533
# EP641 EpisodeReward=-1534.1100482007562
# EP642 EpisodeReward=-1535.7041010709347
# EP643 EpisodeReward=-1060.7833736097352
# EP644 EpisodeReward=-1303.4820515905324
# EP645 EpisodeReward=-1406.1151774149255
# EP646 EpisodeReward=-1520.0458752953803
# EP647 EpisodeReward=-1296.5093930217004
# EP648 EpisodeReward=-1371.6547029288538
# EP649 EpisodeReward=-1523.6732457643216
# EP650 EpisodeReward=-1501.2503790637927
# EP651 EpisodeReward=-1287.3630071265782
# EP652 EpisodeReward=-1453.4501102574814
# EP653 EpisodeReward=-0.49922056103223267
# EP654 EpisodeReward=-1323.8017674537475
# EP655 EpisodeReward=-3.1776627274076326
# EP656 EpisodeReward=-399.44064174778003
# EP657 EpisodeReward=-641.1571692852987
# EP658 EpisodeReward=-651.2463206348343
# EP659 EpisodeReward=-814.0427496538496
# EP660 EpisodeReward=-653.2866896364985
# EP661 EpisodeReward=-644.4124133200831
# EP662 EpisodeReward=-766.3589197158093
# EP663 EpisodeReward=-560.5927301522839
# EP664 EpisodeReward=-524.6605313764925
# EP665 EpisodeReward=-569.9216056691934
# EP666 EpisodeReward=-896.8768584170706
# EP667 EpisodeReward=-1151.1287510400086
# EP668 EpisodeReward=-787.8307782866743
# EP669 EpisodeReward=-514.7715308700107
# EP670 EpisodeReward=-622.7414690023021
# EP671 EpisodeReward=-517.5279694285922
# EP672 EpisodeReward=-650.0329648980342
# EP673 EpisodeReward=-512.437039372032
# EP674 EpisodeReward=-834.7506550869455
# EP675 EpisodeReward=-493.5919722946862
# EP676 EpisodeReward=-834.6411670859112
# EP677 EpisodeReward=-398.8937626059747
# EP678 EpisodeReward=-966.9947005822436
# EP679 EpisodeReward=-565.3302991050115
# EP680 EpisodeReward=-1315.9602410991045
# EP681 EpisodeReward=-1292.7012285332873
# EP682 EpisodeReward=-1337.000332438565
# EP683 EpisodeReward=-131.07952677966506
# EP684 EpisodeReward=-1300.790452608948
# EP685 EpisodeReward=-1403.6818191160794
# EP686 EpisodeReward=-1403.2847506185867
# EP687 EpisodeReward=-390.02526163457196
# EP688 EpisodeReward=-143.4655300261896
# EP689 EpisodeReward=-1350.258865847886
# EP690 EpisodeReward=-1362.2808930746687
# EP691 EpisodeReward=-292.7496949371373
# EP692 EpisodeReward=-1244.7764528168111
# EP693 EpisodeReward=-618.4083946850009
# EP694 EpisodeReward=-1233.9833839049936
# EP695 EpisodeReward=-1319.6513661330523
# EP696 EpisodeReward=-524.2851680549766
# EP697 EpisodeReward=-830.126261583238
# EP698 EpisodeReward=-916.7314712055498
# EP699 EpisodeReward=-1246.913841259361
# EP700 EpisodeReward=-385.3876800535396
# EP701 EpisodeReward=-1376.7796932687822
# EP702 EpisodeReward=-1380.5153941217145
# EP703 EpisodeReward=-659.240252836336
# EP704 EpisodeReward=-736.3864999075138
# EP705 EpisodeReward=-1442.5977241197681
# EP706 EpisodeReward=-811.1777911896687
# EP707 EpisodeReward=-1386.183072224537
# EP708 EpisodeReward=-675.4309757959583
# EP709 EpisodeReward=-1356.2231601288086
# EP710 EpisodeReward=-868.160366539386
# EP711 EpisodeReward=-588.4988051948344
# EP712 EpisodeReward=-425.53072492722674
# EP713 EpisodeReward=-1242.1895431750906
# EP714 EpisodeReward=-1099.490682497105
# EP715 EpisodeReward=-807.0167658710817
# EP716 EpisodeReward=-1241.0116428197887
# EP717 EpisodeReward=-1356.856612440733
# EP718 EpisodeReward=-1344.7292723642458
# EP719 EpisodeReward=-135.56385192186593
# EP720 EpisodeReward=-1359.2808937953168
# EP721 EpisodeReward=-396.65313775190265
# EP722 EpisodeReward=-1354.7389171657678
# EP723 EpisodeReward=-1291.870391424947
# EP724 EpisodeReward=-476.42453370508366
# EP725 EpisodeReward=-1419.6926920256958
# EP726 EpisodeReward=-264.09265365104653
# EP727 EpisodeReward=-1305.9226377447255
# EP728 EpisodeReward=-1389.7718730275205
# EP729 EpisodeReward=-696.3806514457129
# EP730 EpisodeReward=-1440.5409041164928
# EP731 EpisodeReward=-1348.381248813629
# EP732 EpisodeReward=-646.5139244117105
# EP733 EpisodeReward=-774.9412644177413
# EP734 EpisodeReward=-646.5051005454426
# EP735 EpisodeReward=-1210.9111213084684
# EP736 EpisodeReward=-1446.1739829971564
# EP737 EpisodeReward=-648.9743301371645
# EP738 EpisodeReward=-1459.1652352939254
# EP739 EpisodeReward=-1322.6114238996106
# EP740 EpisodeReward=-540.5332049526148
# EP741 EpisodeReward=-1468.7615963343765
# EP742 EpisodeReward=-1241.7974875791951
# EP743 EpisodeReward=-1372.7506113862212
# EP744 EpisodeReward=-1345.1399738428895
# EP745 EpisodeReward=-513.1093945856215
# EP746 EpisodeReward=-646.1306828217137
# EP747 EpisodeReward=-510.14627010048883
# EP748 EpisodeReward=-1360.6968578062342
# EP749 EpisodeReward=-519.5638065004832
# EP750 EpisodeReward=-1283.973048235423
# EP751 EpisodeReward=-1396.7822852261256
# EP752 EpisodeReward=-535.735487329736
# EP753 EpisodeReward=-664.415654615797
# EP754 EpisodeReward=-260.60667125248
# EP755 EpisodeReward=-1369.641735829842
# EP756 EpisodeReward=-1507.3363149251068
# EP757 EpisodeReward=-1516.1746592466734
# EP758 EpisodeReward=-1393.9573261791388
# EP759 EpisodeReward=-1413.9374136423955
# EP760 EpisodeReward=-1225.0739289326634
# EP761 EpisodeReward=-254.87906257445724
# EP762 EpisodeReward=-0.43192889539357676
# EP763 EpisodeReward=-1451.5331047708314
# EP764 EpisodeReward=-1354.3124890973604
# EP765 EpisodeReward=-1487.5860587582008
# EP766 EpisodeReward=-1084.54049355716
# EP767 EpisodeReward=-1362.5698491168841
# EP768 EpisodeReward=-5.867568051983148
# EP769 EpisodeReward=-1384.4823130466054
# EP770 EpisodeReward=-1447.5184794034944
# EP771 EpisodeReward=-1432.896805530535
# EP772 EpisodeReward=-1378.2556203306783
# EP773 EpisodeReward=-377.8056457915639
# EP774 EpisodeReward=-1368.2377626815232
# EP775 EpisodeReward=-136.8861361592892
# EP776 EpisodeReward=-125.73791013651642
# EP777 EpisodeReward=-1339.6159502679466
# EP778 EpisodeReward=-1500.2036986962826
# EP779 EpisodeReward=-447.58040012358134
# EP780 EpisodeReward=-4.927387766078999
# EP781 EpisodeReward=-1478.8964744145144
# EP782 EpisodeReward=-1383.8302827377847
# EP783 EpisodeReward=-472.32461124994836
# EP784 EpisodeReward=-248.66003296753743
# EP785 EpisodeReward=-426.6769140220309
# EP786 EpisodeReward=-1452.961465985692
# EP787 EpisodeReward=-130.28866378311784
# EP788 EpisodeReward=-1379.850986556772
# EP789 EpisodeReward=-1350.3139253151808
# EP790 EpisodeReward=-128.8543588757721
# EP791 EpisodeReward=-6.288141454439523
# EP792 EpisodeReward=-1466.0492335988229
# EP793 EpisodeReward=-639.0060133844603
# EP794 EpisodeReward=-1442.5363445158252
# EP795 EpisodeReward=-1520.982821765927
# EP796 EpisodeReward=-5.955613443207742
# EP797 EpisodeReward=-1521.1089603742898
# EP798 EpisodeReward=-1471.1494107686913
# EP799 EpisodeReward=-1542.4959298209105
# EP800 EpisodeReward=-1418.136674754227
# EP801 EpisodeReward=-4.924624514280892
# EP802 EpisodeReward=-1461.053607646411
# EP803 EpisodeReward=-129.60362687955492
# EP804 EpisodeReward=-1528.1205106821558
# EP805 EpisodeReward=-1365.160140327799
# EP806 EpisodeReward=-132.4698916669708
# EP807 EpisodeReward=-131.68033901324685
# EP808 EpisodeReward=-1499.7243520014429
# EP809 EpisodeReward=-12.445178818363727
# EP810 EpisodeReward=-258.59306373267873
# EP811 EpisodeReward=-3.0374215874689825
# EP812 EpisodeReward=-1571.3496895866185
# EP813 EpisodeReward=-1481.251565233837
# EP814 EpisodeReward=-1508.252259105626
# EP815 EpisodeReward=-1526.5901055650145
# EP816 EpisodeReward=-1623.4681179500724
# EP817 EpisodeReward=-1612.9433628567488
# EP818 EpisodeReward=-3.0492897096780216
# EP819 EpisodeReward=-772.4323672702944
# EP820 EpisodeReward=-5.035858285885512
# EP821 EpisodeReward=-1581.722468652997
# EP822 EpisodeReward=-1524.4191325572253
# EP823 EpisodeReward=-1330.6660337804399
# EP824 EpisodeReward=-1513.9469390989714
# EP825 EpisodeReward=-4.113342136947318
# EP826 EpisodeReward=-4.300310872896457
# EP827 EpisodeReward=-1629.874582422879
# EP828 EpisodeReward=-1498.4006209599036
# EP829 EpisodeReward=-1510.9982626966384
# EP830 EpisodeReward=-140.1561584449553
# EP831 EpisodeReward=-249.8395066431412
# EP832 EpisodeReward=-135.27531701316082
# EP833 EpisodeReward=-1622.5621340675452
# EP834 EpisodeReward=-1507.700441167088
# EP835 EpisodeReward=-1446.3830306441116
# EP836 EpisodeReward=-3.077865389548116
# EP837 EpisodeReward=-1634.6777336872954
# EP838 EpisodeReward=-1617.6740964856
# EP839 EpisodeReward=-1427.8716864928322
# EP840 EpisodeReward=-1375.7039181763494
# EP841 EpisodeReward=-1525.5223156729103
# EP842 EpisodeReward=-1540.365620482035
# EP843 EpisodeReward=-1536.8821489860302
# EP844 EpisodeReward=-1553.5168907984585
# EP845 EpisodeReward=-1643.2304300069648
# EP846 EpisodeReward=-1508.780170098189
# EP847 EpisodeReward=-1254.8579527797092
# EP848 EpisodeReward=-1623.5745418490224
# EP849 EpisodeReward=-1608.228184710043
# EP850 EpisodeReward=-129.76255173709208
# EP851 EpisodeReward=-1458.515429623976
# EP852 EpisodeReward=-429.9166643712683
# EP853 EpisodeReward=-7.619058313290713
# EP854 EpisodeReward=-1532.36872218907
# EP855 EpisodeReward=-1390.8682526227149
# EP856 EpisodeReward=-1516.4182736247292
# EP857 EpisodeReward=-134.60884248006437
# EP858 EpisodeReward=-1528.0466454389586
# EP859 EpisodeReward=-1518.319815157846
# EP860 EpisodeReward=-360.38859363950684
# EP861 EpisodeReward=-268.8985726724983
# EP862 EpisodeReward=-1501.603107687452
# EP863 EpisodeReward=-1520.7574955660555
# EP864 EpisodeReward=-2.363338290519997
# EP865 EpisodeReward=-506.25345024169997
# EP866 EpisodeReward=-1564.85883844657
# EP867 EpisodeReward=-1532.6630163807818
# EP868 EpisodeReward=-263.69996073766345
# EP869 EpisodeReward=-1458.7057864386084
# EP870 EpisodeReward=-13.164752888184598
# EP871 EpisodeReward=-1453.7332569816194
# EP872 EpisodeReward=-914.6944441691679
# EP873 EpisodeReward=-1631.582004961139
# EP874 EpisodeReward=-1043.7274335836676
# EP875 EpisodeReward=-819.7615082684005
# EP876 EpisodeReward=-1634.725052394029
# EP877 EpisodeReward=-522.3025292652352
# EP878 EpisodeReward=-1487.2575683832563
# EP879 EpisodeReward=-1551.116922420255
# EP880 EpisodeReward=-535.441750667594
# EP881 EpisodeReward=-254.33595595170536
# EP882 EpisodeReward=-1463.4142803947398
# EP883 EpisodeReward=-1628.5661787002643
# EP884 EpisodeReward=-6.885808175789397
# EP885 EpisodeReward=-1632.1705267643617
# EP886 EpisodeReward=-1511.27189879903
# EP887 EpisodeReward=-1319.839250896967
# EP888 EpisodeReward=-1.6812437057193135
# EP889 EpisodeReward=-1514.7359906843603
# EP890 EpisodeReward=-1457.909003242175
# EP891 EpisodeReward=-1394.8079296590356
# EP892 EpisodeReward=-1599.1297064852733
# EP893 EpisodeReward=-1546.5563875456985
# EP894 EpisodeReward=-1530.4257051632803
# EP895 EpisodeReward=-248.81579744212087
# EP896 EpisodeReward=-1316.8430187771678
# EP897 EpisodeReward=-1562.2015378184133
# EP898 EpisodeReward=-1574.9206101716575
# EP899 EpisodeReward=-1623.8755556745348
# EP900 EpisodeReward=-129.5830886907071
# EP901 EpisodeReward=-1626.912952883951
# EP902 EpisodeReward=-1559.8177312053504
# EP903 EpisodeReward=-1549.3361495677943
# EP904 EpisodeReward=-1544.299721896139
# EP905 EpisodeReward=-1645.3128772353064
# EP906 EpisodeReward=-386.28231541263364
# EP907 EpisodeReward=-1.4173618194532691
# EP908 EpisodeReward=-131.36965300571563
# EP909 EpisodeReward=-1562.1634062931225
# EP910 EpisodeReward=-1491.3602046607466
# EP911 EpisodeReward=-1456.5309006225323
# EP912 EpisodeReward=-1293.5324495781506
# EP913 EpisodeReward=-649.6181536804403
# EP914 EpisodeReward=-1473.3179702861644
# EP915 EpisodeReward=-250.92780128837342
# EP916 EpisodeReward=-2.6074329319922853
# EP917 EpisodeReward=-0.5912673247256354
# EP918 EpisodeReward=-2.2469021234184567
# EP919 EpisodeReward=-1545.5757278542467
# EP920 EpisodeReward=-1505.2229206757963
# EP921 EpisodeReward=-1547.0598373072944
# EP922 EpisodeReward=-1628.6560628678685
# EP923 EpisodeReward=-126.80132489593068
# EP924 EpisodeReward=-376.6833893430725
# EP925 EpisodeReward=-1004.0736788523014
# EP926 EpisodeReward=-728.1603097246355
# EP927 EpisodeReward=-1523.4191461495386
# EP928 EpisodeReward=-525.1040524091742
# EP929 EpisodeReward=-1531.7857474264538
# EP930 EpisodeReward=-261.7933173888156
# EP931 EpisodeReward=-1539.3523513364894
# EP932 EpisodeReward=-1456.2946134420515
# EP933 EpisodeReward=-1482.0476256218853
# EP934 EpisodeReward=-1641.2985085831385
# EP935 EpisodeReward=-1526.785277702238
# EP936 EpisodeReward=-1551.0215982830866
# EP937 EpisodeReward=-1544.630866634755
# EP938 EpisodeReward=-7.977468590221788
# EP939 EpisodeReward=-786.3802981696422
# EP940 EpisodeReward=-1420.4382740987226
# EP941 EpisodeReward=-1567.7898200782593
# EP942 EpisodeReward=-788.9179474622414
# EP943 EpisodeReward=-770.0334545440743
# EP944 EpisodeReward=-839.4642036146641
# EP945 EpisodeReward=-391.4833732950027
# EP946 EpisodeReward=-136.1249901823548
# EP947 EpisodeReward=-1613.7536742148977
# EP948 EpisodeReward=-134.2993132782397
# EP949 EpisodeReward=-1648.9739963428315
# EP950 EpisodeReward=-1537.3667454708032
# EP951 EpisodeReward=-650.3764102481773
# EP952 EpisodeReward=-1618.499915423891
# EP953 EpisodeReward=-2.0840681385437656
# EP954 EpisodeReward=-1520.1669927012701
# EP955 EpisodeReward=-1542.9343780338543
# EP956 EpisodeReward=-1626.5815531474775
# EP957 EpisodeReward=-1553.8393085606951
# EP958 EpisodeReward=-1523.1300272743579
# EP959 EpisodeReward=-1522.6452700826737
# EP960 EpisodeReward=-3.894557546245279
# EP961 EpisodeReward=-1586.4822228306575
# EP962 EpisodeReward=-13.37462379590962
# EP963 EpisodeReward=-1644.3154708652385
# EP964 EpisodeReward=-6.432830355993884
# EP965 EpisodeReward=-1437.7927443526514
# EP966 EpisodeReward=-1595.0813590326743
# EP967 EpisodeReward=-1523.1755757268209
# EP968 EpisodeReward=-132.73785148713668
# EP969 EpisodeReward=-1430.858964595481
# EP970 EpisodeReward=-1644.0146461504742
# EP971 EpisodeReward=-650.0657492732615
# EP972 EpisodeReward=-548.5350573625892
# EP973 EpisodeReward=-394.13592609363116
# EP974 EpisodeReward=-915.2212049819542
# EP975 EpisodeReward=-138.91025877524123
# EP976 EpisodeReward=-1611.0307056515378
# EP977 EpisodeReward=-371.20347608914557
# EP978 EpisodeReward=-1546.4290423744396
# EP979 EpisodeReward=-1579.6379125990554
# EP980 EpisodeReward=-1521.6872108765403
# EP981 EpisodeReward=-127.64102635229447
# EP982 EpisodeReward=-1565.47512689026
# EP983 EpisodeReward=-1538.1071799923652
# EP984 EpisodeReward=-390.9125653340332
# EP985 EpisodeReward=-1433.9638852938276
# EP986 EpisodeReward=-8.783972939848361
# EP987 EpisodeReward=-1533.0454727938297
# EP988 EpisodeReward=-269.03078950177365
# EP989 EpisodeReward=-520.4818915541904
# EP990 EpisodeReward=-130.0511057517438
# EP991 EpisodeReward=-1519.8948042048592
# EP992 EpisodeReward=-127.10614356941483
# EP993 EpisodeReward=-2.697465984711033
# EP994 EpisodeReward=-371.7474534023587
# EP995 EpisodeReward=-248.94352458736356
# EP996 EpisodeReward=-1522.3570506676547
# EP997 EpisodeReward=-128.1855523250998
# EP998 EpisodeReward=-2.405272727437025
# EP999 EpisodeReward=-131.9572632941908
